# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# 3. Create a set of 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d837b9a0363f8eb9404b5ab938c1f5c8

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d837b9a0363f8eb9404b5ab938c1f5c8&q=Boston

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
#city_weather

# %%
# Get the JSON text of the 'Get' request.
#city_weather.json()

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
print(f"Total Number of cities: {len(city_data)}")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | winneba
# Processing Record 2 of Set 1 | codrington
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | barrow
# Processing Record 5 of Set 1 | bengkulu
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | fairbanks
# Processing Record 8 of Set 1 | lakhipur
# Processing Record 9 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 1 | lavrentiya
# Processing Record 11 of Set 1 | kichera
# Processing Record 12 of Set 1 | norman wells
# Processing Record 13 of Set 1 | leningradskiy
# Processing Record 14 of Set 1 | alto araguaia
# Processing Record 15 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 16 of Set 1 | san patricio
# Processing Record 17 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 1 | sitka
# Processing Record 19 of Set 1 | hithadhoo
# Processing Record 20 of Set 1 | vardo
# Processing Record 21 of Set 1 | khatanga
# Processing Record 22 of Set 1 | tasiilaq
# Processing Record 23 of Set 1 | mungwi
# Processing Record 24 of Set 1 | gurskoye
# City not found. Skipping...
# Processing Record 25 of Set 1 | east london
# Processing Record 26 of Set 1 | georgetown
# Processing Record 27 of Set 1 | salalah
# Processing Record 28 of Set 1 | lubao
# Processing Record 29 of Set 1 | new norfolk
# Processing Record 30 of Set 1 | rio bueno
# Processing Record 31 of Set 1 | kargasok
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | anshun
# Processing Record 34 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 1 | butaritari
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | thompson
# Processing Record 39 of Set 1 | ponta do sol
# Processing Record 40 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 1 | yellowknife
# Processing Record 42 of Set 1 | sao jose da coroa grande
# Processing Record 43 of Set 1 | lewistown
# Processing Record 44 of Set 1 | san jose
# Processing Record 45 of Set 1 | komsomolskiy
# Processing Record 46 of Set 1 | geraldton
# Processing Record 47 of Set 1 | bluff
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | jamestown
# Processing Record 50 of Set 1 | katsuura
# Processing Record 1 of Set 2 | cayenne
# Processing Record 2 of Set 2 | port alfred
# Processing Record 3 of Set 2 | belousovka
# Processing Record 4 of Set 2 | san juan
# Processing Record 5 of Set 2 | stornoway
# Processing Record 6 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 2 | pachino
# Processing Record 8 of Set 2 | saint george
# Processing Record 9 of Set 2 | mar del plata
# Processing Record 10 of Set 2 | serenje
# Processing Record 11 of Set 2 | nehe
# Processing Record 12 of Set 2 | upernavik
# Processing Record 13 of Set 2 | seoul
# Processing Record 14 of Set 2 | cherskiy
# Processing Record 15 of Set 2 | darhan
# Processing Record 16 of Set 2 | airai
# Processing Record 17 of Set 2 | vaini
# Processing Record 18 of Set 2 | lata
# Processing Record 19 of Set 2 | kavieng
# Processing Record 20 of Set 2 | dikson
# Processing Record 21 of Set 2 | tsienyane
# City not found. Skipping...
# Processing Record 22 of Set 2 | ola
# Processing Record 23 of Set 2 | arraial do cabo
# Processing Record 24 of Set 2 | perigueux
# Processing Record 25 of Set 2 | ballina
# Processing Record 26 of Set 2 | sisophon
# Processing Record 27 of Set 2 | iqaluit
# Processing Record 28 of Set 2 | tuktoyaktuk
# Processing Record 29 of Set 2 | avarua
# Processing Record 30 of Set 2 | saskylakh
# Processing Record 31 of Set 2 | biltine
# Processing Record 32 of Set 2 | novopokrovka
# Processing Record 33 of Set 2 | bobo dioulasso
# Processing Record 34 of Set 2 | xining
# Processing Record 35 of Set 2 | berlevag
# Processing Record 36 of Set 2 | hobart
# Processing Record 37 of Set 2 | saint-philippe
# Processing Record 38 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 2 | severo-kurilsk
# Processing Record 40 of Set 2 | kapaa
# Processing Record 41 of Set 2 | phan rang
# City not found. Skipping...
# Processing Record 42 of Set 2 | mahebourg
# Processing Record 43 of Set 2 | ornskoldsvik
# Processing Record 44 of Set 2 | wallaceburg
# Processing Record 45 of Set 2 | vanimo
# Processing Record 46 of Set 2 | nizhneangarsk
# Processing Record 47 of Set 2 | kavaratti
# Processing Record 48 of Set 2 | touros
# Processing Record 49 of Set 2 | aykino
# Processing Record 50 of Set 2 | kapuskasing
# Processing Record 1 of Set 3 | bredasdorp
# Processing Record 2 of Set 3 | port elizabeth
# Processing Record 3 of Set 3 | nicoya
# Processing Record 4 of Set 3 | alofi
# Processing Record 5 of Set 3 | hermanus
# Processing Record 6 of Set 3 | qaanaaq
# Processing Record 7 of Set 3 | chicama
# Processing Record 8 of Set 3 | vestmannaeyjar
# Processing Record 9 of Set 3 | meulaboh
# Processing Record 10 of Set 3 | fayaoue
# Processing Record 11 of Set 3 | ponta delgada
# Processing Record 12 of Set 3 | aguas vermelhas
# Processing Record 13 of Set 3 | awjilah
# Processing Record 14 of Set 3 | celestun
# Processing Record 15 of Set 3 | agadir
# Processing Record 16 of Set 3 | bereslavka
# Processing Record 17 of Set 3 | haines junction
# Processing Record 18 of Set 3 | gucheng
# Processing Record 19 of Set 3 | saint-augustin
# Processing Record 20 of Set 3 | carnarvon
# Processing Record 21 of Set 3 | jagalur
# Processing Record 22 of Set 3 | lebu
# Processing Record 23 of Set 3 | puerto ayora
# Processing Record 24 of Set 3 | walvis bay
# Processing Record 25 of Set 3 | stromness
# Processing Record 26 of Set 3 | manta
# Processing Record 27 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 3 | wladyslawowo
# Processing Record 29 of Set 3 | borogontsy
# Processing Record 30 of Set 3 | agirish
# Processing Record 31 of Set 3 | torbay
# Processing Record 32 of Set 3 | ilulissat
# Processing Record 33 of Set 3 | hilo
# Processing Record 34 of Set 3 | souillac
# Processing Record 35 of Set 3 | tiksi
# Processing Record 36 of Set 3 | plettenberg bay
# Processing Record 37 of Set 3 | aksarka
# Processing Record 38 of Set 3 | manturovo
# Processing Record 39 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 3 | yining
# Processing Record 42 of Set 3 | griffith
# Processing Record 43 of Set 3 | baykit
# Processing Record 44 of Set 3 | mariental
# Processing Record 45 of Set 3 | provideniya
# Processing Record 46 of Set 3 | san rafael
# Processing Record 47 of Set 3 | kaitangata
# Processing Record 48 of Set 3 | marawi
# Processing Record 49 of Set 3 | kupang
# Processing Record 50 of Set 3 | bambous virieux
# Processing Record 1 of Set 4 | asau
# Processing Record 2 of Set 4 | voh
# Processing Record 3 of Set 4 | yeppoon
# Processing Record 4 of Set 4 | mount gambier
# Processing Record 5 of Set 4 | itupeva
# Processing Record 6 of Set 4 | kingman
# Processing Record 7 of Set 4 | ahipara
# Processing Record 8 of Set 4 | atuona
# Processing Record 9 of Set 4 | bandarbeyla
# Processing Record 10 of Set 4 | victoria
# Processing Record 11 of Set 4 | srednekolymsk
# Processing Record 12 of Set 4 | floro
# Processing Record 13 of Set 4 | lethem
# Processing Record 14 of Set 4 | hami
# Processing Record 15 of Set 4 | port blair
# Processing Record 16 of Set 4 | la rioja
# Processing Record 17 of Set 4 | juneau
# Processing Record 18 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 19 of Set 4 | takoradi
# Processing Record 20 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 21 of Set 4 | albany
# Processing Record 22 of Set 4 | cidreira
# Processing Record 23 of Set 4 | abu samrah
# Processing Record 24 of Set 4 | fortuna
# Processing Record 25 of Set 4 | mizan teferi
# Processing Record 26 of Set 4 | upington
# Processing Record 27 of Set 4 | puerto escondido
# Processing Record 28 of Set 4 | bustonkala
# City not found. Skipping...
# Processing Record 29 of Set 4 | north bend
# Processing Record 30 of Set 4 | beringovskiy
# Processing Record 31 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 4 | gewane
# Processing Record 33 of Set 4 | shakawe
# Processing Record 34 of Set 4 | svetlogorsk
# Processing Record 35 of Set 4 | concarneau
# Processing Record 36 of Set 4 | klaksvik
# Processing Record 37 of Set 4 | pisco
# Processing Record 38 of Set 4 | ancud
# Processing Record 39 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 4 | kodiak
# Processing Record 41 of Set 4 | tautira
# Processing Record 42 of Set 4 | duncan
# Processing Record 43 of Set 4 | sinnamary
# Processing Record 44 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 45 of Set 4 | saint anthony
# Processing Record 46 of Set 4 | tuatapere
# Processing Record 47 of Set 4 | hasaki
# Processing Record 48 of Set 4 | alice springs
# Processing Record 49 of Set 4 | bhind
# Processing Record 50 of Set 4 | nikolskoye
# Processing Record 1 of Set 5 | shitkino
# Processing Record 2 of Set 5 | naze
# Processing Record 3 of Set 5 | luderitz
# Processing Record 4 of Set 5 | plouzane
# Processing Record 5 of Set 5 | burgos
# Processing Record 6 of Set 5 | jalu
# Processing Record 7 of Set 5 | eenhana
# Processing Record 8 of Set 5 | skjervoy
# Processing Record 9 of Set 5 | navabad
# City not found. Skipping...
# Processing Record 10 of Set 5 | edd
# Processing Record 11 of Set 5 | talara
# Processing Record 12 of Set 5 | hirara
# Processing Record 13 of Set 5 | olinda
# Processing Record 14 of Set 5 | lagoa
# Processing Record 15 of Set 5 | gubkinskiy
# Processing Record 16 of Set 5 | kruisfontein
# Processing Record 17 of Set 5 | nanortalik
# Processing Record 18 of Set 5 | fagersta
# Processing Record 19 of Set 5 | nelson bay
# Processing Record 20 of Set 5 | noumea
# Processing Record 21 of Set 5 | gornoye loo
# Processing Record 22 of Set 5 | veraval
# Processing Record 23 of Set 5 | castro
# Processing Record 24 of Set 5 | luganville
# Processing Record 25 of Set 5 | talnakh
# Processing Record 26 of Set 5 | erenhot
# Processing Record 27 of Set 5 | loikaw
# Processing Record 28 of Set 5 | hamilton
# Processing Record 29 of Set 5 | sawakin
# Processing Record 30 of Set 5 | chokurdakh
# Processing Record 31 of Set 5 | warri
# Processing Record 32 of Set 5 | port hardy
# Processing Record 33 of Set 5 | shimoda
# Processing Record 34 of Set 5 | bethel
# Processing Record 35 of Set 5 | dubbo
# Processing Record 36 of Set 5 | qasigiannguit
# Processing Record 37 of Set 5 | saint-georges
# Processing Record 38 of Set 5 | state college
# Processing Record 39 of Set 5 | tual
# Processing Record 40 of Set 5 | mackay
# Processing Record 41 of Set 5 | pangnirtung
# Processing Record 42 of Set 5 | yangambi
# Processing Record 43 of Set 5 | kalulushi
# Processing Record 44 of Set 5 | saldanha
# Processing Record 45 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 46 of Set 5 | la ronge
# Processing Record 47 of Set 5 | kenai
# Processing Record 48 of Set 5 | bursa
# Processing Record 49 of Set 5 | oranjemund
# Processing Record 50 of Set 5 | waipawa
# Processing Record 1 of Set 6 | kuching
# Processing Record 2 of Set 6 | half moon bay
# Processing Record 3 of Set 6 | buala
# Processing Record 4 of Set 6 | college
# Processing Record 5 of Set 6 | maldonado
# Processing Record 6 of Set 6 | maragogi
# Processing Record 7 of Set 6 | sept-iles
# Processing Record 8 of Set 6 | waddan
# Processing Record 9 of Set 6 | merauke
# Processing Record 10 of Set 6 | kirakira
# Processing Record 11 of Set 6 | madimba
# Processing Record 12 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 6 | sabzevar
# Processing Record 14 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 15 of Set 6 | boyolangu
# Processing Record 16 of Set 6 | heihe
# Processing Record 17 of Set 6 | seidu
# Processing Record 18 of Set 6 | comodoro rivadavia
# Processing Record 19 of Set 6 | kamen-na-obi
# Processing Record 20 of Set 6 | kamaishi
# Processing Record 21 of Set 6 | cabo san lucas
# Processing Record 22 of Set 6 | neiafu
# Processing Record 23 of Set 6 | omboue
# Processing Record 24 of Set 6 | husavik
# Processing Record 25 of Set 6 | qaqortoq
# Processing Record 26 of Set 6 | corvallis
# Processing Record 27 of Set 6 | erzin
# Processing Record 28 of Set 6 | scottsburgh
# City not found. Skipping...
# Processing Record 29 of Set 6 | chake chake
# Processing Record 30 of Set 6 | mecca
# Processing Record 31 of Set 6 | sao filipe
# Processing Record 32 of Set 6 | barcelos
# Processing Record 33 of Set 6 | faanui
# Processing Record 34 of Set 6 | ivrea
# Processing Record 35 of Set 6 | lompoc
# Processing Record 36 of Set 6 | nishihara
# Processing Record 37 of Set 6 | yeniseysk
# Processing Record 38 of Set 6 | faya
# Processing Record 39 of Set 6 | esperance
# Processing Record 40 of Set 6 | ribeira grande
# Processing Record 41 of Set 6 | limoges
# Processing Record 42 of Set 6 | pevek
# Processing Record 43 of Set 6 | kholtoson
# Processing Record 44 of Set 6 | longyearbyen
# Processing Record 45 of Set 6 | sembe
# Processing Record 46 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 6 | galgani
# City not found. Skipping...
# Processing Record 48 of Set 6 | camana
# Processing Record 49 of Set 6 | kalmunai
# Processing Record 50 of Set 6 | villa rica
# Processing Record 1 of Set 7 | tiznit
# Processing Record 2 of Set 7 | clyde river
# Processing Record 3 of Set 7 | krasnoarmeysk
# Processing Record 4 of Set 7 | ostersund
# Processing Record 5 of Set 7 | udachnyy
# Processing Record 6 of Set 7 | ketchikan
# Processing Record 7 of Set 7 | kenora
# Processing Record 8 of Set 7 | liverpool
# Processing Record 9 of Set 7 | fucecchio
# Processing Record 10 of Set 7 | manado
# Processing Record 11 of Set 7 | saqqez
# Processing Record 12 of Set 7 | khandagayty
# Processing Record 13 of Set 7 | mitsamiouli
# Processing Record 14 of Set 7 | thanh hoa
# Processing Record 15 of Set 7 | vila velha
# Processing Record 16 of Set 7 | pucallpa
# Processing Record 17 of Set 7 | imeni poliny osipenko
# Processing Record 18 of Set 7 | san isidro
# Processing Record 19 of Set 7 | raga
# Processing Record 20 of Set 7 | auki
# Processing Record 21 of Set 7 | tabou
# Processing Record 22 of Set 7 | bonavista
# Processing Record 23 of Set 7 | praya
# Processing Record 24 of Set 7 | kommunar
# Processing Record 25 of Set 7 | margate
# Processing Record 26 of Set 7 | ofunato
# Processing Record 27 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 7 | okato
# Processing Record 29 of Set 7 | odweyne
# Processing Record 30 of Set 7 | payson
# Processing Record 31 of Set 7 | burias
# Processing Record 32 of Set 7 | lorengau
# Processing Record 33 of Set 7 | ewa beach
# Processing Record 34 of Set 7 | preobrazheniye
# Processing Record 35 of Set 7 | chegutu
# Processing Record 36 of Set 7 | port augusta
# Processing Record 37 of Set 7 | dongying
# Processing Record 38 of Set 7 | nouakchott
# Processing Record 39 of Set 7 | kholodnyy
# Processing Record 40 of Set 7 | moses lake
# Processing Record 41 of Set 7 | carutapera
# Processing Record 42 of Set 7 | cam ranh
# Processing Record 43 of Set 7 | vilhena
# Processing Record 44 of Set 7 | bjornevatn
# Processing Record 45 of Set 7 | vostok
# Processing Record 46 of Set 7 | caravelas
# Processing Record 47 of Set 7 | aden
# Processing Record 48 of Set 7 | ostrovnoy
# Processing Record 49 of Set 7 | lakselv
# Processing Record 50 of Set 7 | parrita
# Processing Record 1 of Set 8 | huilong
# Processing Record 2 of Set 8 | moron
# Processing Record 3 of Set 8 | okhotsk
# Processing Record 4 of Set 8 | evensk
# Processing Record 5 of Set 8 | ambilobe
# Processing Record 6 of Set 8 | gambela
# Processing Record 7 of Set 8 | lentekhi
# Processing Record 8 of Set 8 | conde
# Processing Record 9 of Set 8 | nuuk
# Processing Record 10 of Set 8 | novoilinsk
# Processing Record 11 of Set 8 | athabasca
# Processing Record 12 of Set 8 | bubaque
# Processing Record 13 of Set 8 | kudahuvadhoo
# Processing Record 14 of Set 8 | non sang
# Processing Record 15 of Set 8 | champerico
# Processing Record 16 of Set 8 | doha
# Processing Record 17 of Set 8 | tashigang
# Processing Record 18 of Set 8 | anloga
# Processing Record 19 of Set 8 | varzea da palma
# Processing Record 20 of Set 8 | yar-sale
# Processing Record 21 of Set 8 | tonj
# Processing Record 22 of Set 8 | khandbari
# Processing Record 23 of Set 8 | richards bay
# Processing Record 24 of Set 8 | kodinar
# Processing Record 25 of Set 8 | muzhi
# Processing Record 26 of Set 8 | kilindoni
# Processing Record 27 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 28 of Set 8 | karratha
# Processing Record 29 of Set 8 | ayotzintepec
# Processing Record 30 of Set 8 | alekseyevsk
# Processing Record 31 of Set 8 | narsaq
# Processing Record 32 of Set 8 | constitucion
# Processing Record 33 of Set 8 | vao
# Processing Record 34 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 8 | necochea
# Processing Record 36 of Set 8 | ixtapa
# Processing Record 37 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 39 of Set 8 | aranos
# Processing Record 40 of Set 8 | galway
# Processing Record 41 of Set 8 | staryy nadym
# Processing Record 42 of Set 8 | dingle
# Processing Record 43 of Set 8 | cabedelo
# Processing Record 44 of Set 8 | floresti
# Processing Record 45 of Set 8 | barentu
# Processing Record 46 of Set 8 | guerrero negro
# Processing Record 47 of Set 8 | challapata
# Processing Record 48 of Set 8 | kijang
# Processing Record 49 of Set 8 | shumskiy
# Processing Record 50 of Set 8 | skibbereen
# Processing Record 1 of Set 9 | maxixe
# Processing Record 2 of Set 9 | sola
# Processing Record 3 of Set 9 | shenjiamen
# Processing Record 4 of Set 9 | surskoye
# Processing Record 5 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 6 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 9 | luwingu
# Processing Record 8 of Set 9 | bauchi
# Processing Record 9 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 10 of Set 9 | mayumba
# Processing Record 11 of Set 9 | cap malheureux
# Processing Record 12 of Set 9 | belaya gora
# Processing Record 13 of Set 9 | tlahualilo
# City not found. Skipping...
# Processing Record 14 of Set 9 | binzhou
# Processing Record 15 of Set 9 | cotonou
# Processing Record 16 of Set 9 | pahrump
# Processing Record 17 of Set 9 | fort saint james
# Processing Record 18 of Set 9 | erzurum
# Processing Record 19 of Set 9 | gerash
# Processing Record 20 of Set 9 | bonthe
# Processing Record 21 of Set 9 | san quintin
# Processing Record 22 of Set 9 | wad rawah
# Processing Record 23 of Set 9 | we
# City not found. Skipping...
# Processing Record 24 of Set 9 | dicabisagan
# Processing Record 25 of Set 9 | isangel
# Processing Record 26 of Set 9 | qom
# Processing Record 27 of Set 9 | ust-ishim
# Processing Record 28 of Set 9 | wewak
# Processing Record 29 of Set 9 | naustdal
# Processing Record 30 of Set 9 | maumere
# Processing Record 31 of Set 9 | maraa
# Processing Record 32 of Set 9 | isla vista
# Processing Record 33 of Set 9 | nador
# Processing Record 34 of Set 9 | tupancireta
# Processing Record 35 of Set 9 | rawson
# Processing Record 36 of Set 9 | kieta
# Processing Record 37 of Set 9 | salacgriva
# Processing Record 38 of Set 9 | morondava
# Processing Record 39 of Set 9 | tilichiki
# Processing Record 40 of Set 9 | bilma
# Processing Record 41 of Set 9 | egvekinot
# Processing Record 42 of Set 9 | ashington
# Processing Record 43 of Set 9 | kharp
# Processing Record 44 of Set 9 | kawalu
# Processing Record 45 of Set 9 | asfi
# Processing Record 46 of Set 9 | berlin
# Processing Record 47 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 9 | westport
# Processing Record 49 of Set 9 | leh
# Processing Record 50 of Set 9 | mount isa
# Processing Record 1 of Set 10 | hammerfest
# Processing Record 2 of Set 10 | svobodnyy
# Processing Record 3 of Set 10 | kurilsk
# Processing Record 4 of Set 10 | inuvik
# Processing Record 5 of Set 10 | dire dawa
# Processing Record 6 of Set 10 | homer
# Processing Record 7 of Set 10 | rabat
# Processing Record 8 of Set 10 | coquimbo
# Processing Record 9 of Set 10 | mahajanga
# Processing Record 10 of Set 10 | diu
# Processing Record 11 of Set 10 | khudumelapye
# Processing Record 12 of Set 10 | vysokogornyy
# Processing Record 13 of Set 10 | maebaru
# Processing Record 14 of Set 10 | mastic beach
# Processing Record 15 of Set 10 | saint-francois
# Processing Record 16 of Set 10 | doctor juan leon mallorquin
# Processing Record 17 of Set 10 | axim
# Processing Record 18 of Set 10 | oyama
# Processing Record 19 of Set 10 | baghdad
# Processing Record 20 of Set 10 | cabatuan
# Processing Record 21 of Set 10 | ushibuka
# Processing Record 22 of Set 10 | torquay
# Processing Record 23 of Set 10 | magaria
# Processing Record 24 of Set 10 | balingasay
# Processing Record 25 of Set 10 | palu
# Processing Record 26 of Set 10 | okha
# Processing Record 27 of Set 10 | calella
# Processing Record 28 of Set 10 | nchelenge
# Processing Record 29 of Set 10 | tromso
# Processing Record 30 of Set 10 | hambantota
# Processing Record 31 of Set 10 | kiunga
# Processing Record 32 of Set 10 | zemio
# Processing Record 33 of Set 10 | semey
# Processing Record 34 of Set 10 | kortkeros
# Processing Record 35 of Set 10 | mareeba
# Processing Record 36 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 37 of Set 10 | lalomanu
# City not found. Skipping...
# Processing Record 38 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 39 of Set 10 | teya
# Processing Record 40 of Set 10 | mazagao
# Processing Record 41 of Set 10 | vorukh
# Processing Record 42 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 43 of Set 10 | musoma
# Processing Record 44 of Set 10 | inhambane
# Processing Record 45 of Set 10 | kencong
# Processing Record 46 of Set 10 | palmer
# Processing Record 47 of Set 10 | high level
# Processing Record 48 of Set 10 | santarem
# Processing Record 49 of Set 10 | hadejia
# Processing Record 50 of Set 10 | borgo san dalmazzo
# Processing Record 1 of Set 11 | sur
# Processing Record 2 of Set 11 | kalmar
# Processing Record 3 of Set 11 | zagra
# Processing Record 4 of Set 11 | te anau
# Processing Record 5 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 6 of Set 11 | ixtlahuacan del rio
# Processing Record 7 of Set 11 | chengdu
# Processing Record 8 of Set 11 | khalimbekaul
# Processing Record 9 of Set 11 | nome
# Processing Record 10 of Set 11 | champasak
# Processing Record 11 of Set 11 | port said
# Processing Record 12 of Set 11 | erdenet
# Processing Record 13 of Set 11 | praia da vitoria
# Processing Record 14 of Set 11 | buchanan
# Processing Record 15 of Set 11 | namanga
# Processing Record 16 of Set 11 | yarmouth
# Processing Record 17 of Set 11 | zambezi
# Processing Record 18 of Set 11 | pandan
# Processing Record 19 of Set 11 | fasa
# Processing Record 20 of Set 11 | chuy
# Processing Record 21 of Set 11 | la asuncion
# Processing Record 22 of Set 11 | padang
# Processing Record 23 of Set 11 | ulladulla
# Processing Record 24 of Set 11 | harrisburg
# Processing Record 25 of Set 11 | cerea
# Processing Record 26 of Set 11 | smithers
# Processing Record 27 of Set 11 | tawang
# Processing Record 28 of Set 11 | vredendal
# Processing Record 29 of Set 11 | talsi
# Processing Record 30 of Set 11 | beitbridge
# Processing Record 31 of Set 11 | mpwapwa
# Processing Record 32 of Set 11 | paamiut
# Processing Record 33 of Set 11 | hay river
# Processing Record 34 of Set 11 | buta
# Processing Record 35 of Set 11 | nanchang
# Processing Record 36 of Set 11 | whitehorse
# Processing Record 37 of Set 11 | vagur
# Processing Record 38 of Set 11 | quatre cocos
# Processing Record 39 of Set 11 | tabuk
# Processing Record 40 of Set 11 | orlik
# Processing Record 41 of Set 11 | alwar
# Processing Record 42 of Set 11 | tuim
# Processing Record 43 of Set 11 | general pico
# Processing Record 44 of Set 11 | viedma
# Processing Record 45 of Set 11 | grindavik
# Processing Record 46 of Set 11 | port lincoln
# Processing Record 47 of Set 11 | manokwari
# Processing Record 48 of Set 11 | akyab
# Processing Record 49 of Set 11 | ous
# Processing Record 50 of Set 11 | ormara
# Processing Record 1 of Set 12 | menongue
# Processing Record 2 of Set 12 | puerto baquerizo moreno
# Processing Record 3 of Set 12 | fez
# Processing Record 4 of Set 12 | belem de sao francisco
# Processing Record 5 of Set 12 | yemelyanovo
# Processing Record 6 of Set 12 | thinadhoo
# Processing Record 7 of Set 12 | beihai
# Processing Record 8 of Set 12 | visby
# Processing Record 9 of Set 12 | otane
# Processing Record 10 of Set 12 | inta
# Processing Record 11 of Set 12 | kasongo-lunda
# Processing Record 12 of Set 12 | vzmorye
# Processing Record 13 of Set 12 | empalme
# Processing Record 14 of Set 12 | dunedin
# Processing Record 15 of Set 12 | mandalgovi
# Processing Record 16 of Set 12 | mersing
# Processing Record 17 of Set 12 | lyubytino
# Processing Record 18 of Set 12 | brae
# Processing Record 19 of Set 12 | ombessa
# Processing Record 20 of Set 12 | itarema
# Processing Record 21 of Set 12 | poltavka
# Processing Record 22 of Set 12 | iiyama
# Processing Record 23 of Set 12 | kungurtug
# Processing Record 24 of Set 12 | lensk
# Processing Record 25 of Set 12 | payyannur
# Processing Record 26 of Set 12 | marsaxlokk
# Processing Record 27 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 12 | progreso
# Processing Record 29 of Set 12 | grants
# Processing Record 30 of Set 12 | sakakah
# Processing Record 31 of Set 12 | sarab
# Processing Record 32 of Set 12 | kloulklubed
# Processing Record 33 of Set 12 | arlit
# Processing Record 34 of Set 12 | bolgatanga
# Processing Record 35 of Set 12 | albac
# Processing Record 36 of Set 12 | denia
# Processing Record 37 of Set 12 | darab
# Processing Record 38 of Set 12 | mithi
# Processing Record 39 of Set 12 | dera din panah
# City not found. Skipping...
# Processing Record 40 of Set 12 | sindi
# Processing Record 41 of Set 12 | dongsheng
# Processing Record 42 of Set 12 | vestmanna
# Processing Record 43 of Set 12 | mocuba
# Processing Record 44 of Set 12 | corinto
# Processing Record 45 of Set 12 | miri
# Processing Record 46 of Set 12 | puerto carreno
# Processing Record 47 of Set 12 | saint-pierre
# Processing Record 48 of Set 12 | lovozero
# Processing Record 49 of Set 12 | bilibino
# Processing Record 50 of Set 12 | poum
# Processing Record 1 of Set 13 | gillette
# Processing Record 2 of Set 13 | shelburne
# Processing Record 3 of Set 13 | ambanja
# Processing Record 4 of Set 13 | trincomalee
# Processing Record 5 of Set 13 | colac
# Processing Record 6 of Set 13 | kulhudhuffushi
# Processing Record 7 of Set 13 | bambanglipuro
# Processing Record 8 of Set 13 | havelock
# Processing Record 9 of Set 13 | nsanje
# Processing Record 10 of Set 13 | plaiesii-de-jos
# City not found. Skipping...
# Processing Record 11 of Set 13 | polyarnyy
# Processing Record 12 of Set 13 | qandahar
# City not found. Skipping...
# Processing Record 13 of Set 13 | kerema
# Processing Record 14 of Set 13 | houma
# Processing Record 15 of Set 13 | ambulu
# Processing Record 16 of Set 13 | kununurra
# Processing Record 17 of Set 13 | palora
# Processing Record 18 of Set 13 | roma
# Processing Record 19 of Set 13 | burnie
# Processing Record 20 of Set 13 | uman
# Processing Record 21 of Set 13 | omsukchan
# Processing Record 22 of Set 13 | urengoy
# Processing Record 23 of Set 13 | pochutla
# Processing Record 24 of Set 13 | namibe
# Processing Record 25 of Set 13 | aripuana
# Processing Record 26 of Set 13 | oussouye
# Processing Record 27 of Set 13 | balkanabat
# Processing Record 28 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 13 | sorland
# Processing Record 30 of Set 13 | tura
# Processing Record 31 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 32 of Set 13 | bhanjanagar
# Processing Record 33 of Set 13 | aban
# Processing Record 34 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 35 of Set 13 | challans
# Processing Record 36 of Set 13 | jacareacanga
# Processing Record 37 of Set 13 | constantine
# Processing Record 38 of Set 13 | san andres
# Processing Record 39 of Set 13 | rudnichnyy
# Processing Record 40 of Set 13 | tazovskiy
# Processing Record 41 of Set 13 | svay rieng
# Processing Record 42 of Set 13 | adrar
# Processing Record 43 of Set 13 | indian head
# Processing Record 44 of Set 13 | sovetskaya
# Processing Record 45 of Set 13 | san pedro
# Processing Record 46 of Set 13 | okmulgee
# Processing Record 47 of Set 13 | kaka
# Processing Record 48 of Set 13 | avera
# Processing Record 49 of Set 13 | qandala
# Processing Record 50 of Set 13 | praia
# Processing Record 1 of Set 14 | glace bay
# Processing Record 2 of Set 14 | santiago del estero
# Processing Record 3 of Set 14 | new glasgow
# Processing Record 4 of Set 14 | the valley
# Processing Record 5 of Set 14 | riyadh
# Processing Record 6 of Set 14 | khani
# Processing Record 7 of Set 14 | ulaangom
# Processing Record 8 of Set 14 | obertshausen
# Processing Record 9 of Set 14 | iranshahr
# Processing Record 10 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 11 of Set 14 | lieksa
# Processing Record 12 of Set 14 | muroto
# Processing Record 13 of Set 14 | portales
# Processing Record 14 of Set 14 | kapiri mposhi
# Processing Record 15 of Set 14 | ahtopol
# Processing Record 16 of Set 14 | jiuquan
# Processing Record 17 of Set 14 | muli
# Processing Record 18 of Set 14 | mehamn
# Processing Record 19 of Set 14 | ahumada
# City not found. Skipping...
# Processing Record 20 of Set 14 | vangaindrano
# Processing Record 21 of Set 14 | saint-joseph
# Processing Record 22 of Set 14 | los llanos de aridane
# Processing Record 23 of Set 14 | deputatskiy
# Processing Record 24 of Set 14 | kathu
# Processing Record 25 of Set 14 | benicarlo
# Processing Record 26 of Set 14 | maicao
# Processing Record 27 of Set 14 | bogdanci
# Processing Record 28 of Set 14 | manaus
# Processing Record 29 of Set 14 | banyo
# Processing Record 30 of Set 14 | caiaponia
# Processing Record 31 of Set 14 | scarborough
# Processing Record 32 of Set 14 | krasnyy kut
# Processing Record 33 of Set 14 | aklavik
# Processing Record 34 of Set 14 | port hawkesbury
# Processing Record 35 of Set 14 | laguna
# Processing Record 36 of Set 14 | marsh harbour
# Processing Record 37 of Set 14 | elda
# Processing Record 38 of Set 14 | lahij
# Processing Record 39 of Set 14 | amga
# Processing Record 40 of Set 14 | agua dulce
# Processing Record 41 of Set 14 | douentza
# Processing Record 42 of Set 14 | taltal
# Processing Record 43 of Set 14 | valiug
# City not found. Skipping...
# Processing Record 44 of Set 14 | dawei
# Processing Record 45 of Set 14 | muncar
# Processing Record 46 of Set 14 | thunder bay
# Processing Record 47 of Set 14 | play cu
# City not found. Skipping...
# Processing Record 48 of Set 14 | crib point
# Processing Record 49 of Set 14 | nabire
# Processing Record 50 of Set 14 | krabi
# Processing Record 1 of Set 15 | kathmandu
# Processing Record 2 of Set 15 | otjiwarongo
# Processing Record 3 of Set 15 | portland
# Processing Record 4 of Set 15 | tir pol
# City not found. Skipping...
# Processing Record 5 of Set 15 | omidiyeh
# Processing Record 6 of Set 15 | goose creek
# Processing Record 7 of Set 15 | belmonte
# Processing Record 8 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 15 | kirovskiy
# Processing Record 10 of Set 15 | chibuto
# Processing Record 11 of Set 15 | shieli
# Processing Record 12 of Set 15 | krasnyy bogatyr
# Processing Record 13 of Set 15 | benghazi
# Processing Record 14 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 15 of Set 15 | hoeselt
# Processing Record 16 of Set 15 | suchiapa
# Processing Record 17 of Set 15 | daru
# Processing Record 18 of Set 15 | siilinjarvi
# Processing Record 19 of Set 15 | jujuy
# City not found. Skipping...
# Processing Record 20 of Set 15 | lanigan
# Processing Record 21 of Set 15 | samarai
# Processing Record 22 of Set 15 | chapais
# Processing Record 23 of Set 15 | ulverstone
# Processing Record 24 of Set 15 | copiapo
# Processing Record 25 of Set 15 | dzilam gonzalez
# Processing Record 26 of Set 15 | pauri
# Processing Record 27 of Set 15 | tabas
# Processing Record 28 of Set 15 | hofn
# Processing Record 29 of Set 15 | paka
# Processing Record 30 of Set 15 | ituni
# City not found. Skipping...
# Processing Record 31 of Set 15 | mahon
# Processing Record 32 of Set 15 | igarka
# Processing Record 33 of Set 15 | sri aman
# Processing Record 34 of Set 15 | miraflores
# Processing Record 35 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 36 of Set 15 | yabrud
# Processing Record 37 of Set 15 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 38 of Set 15 | lar
# Processing Record 39 of Set 15 | pombas
# Processing Record 40 of Set 15 | zeerust
# Processing Record 41 of Set 15 | maamba
# Processing Record 42 of Set 15 | zhangye
# Processing Record 43 of Set 15 | road town
# Processing Record 44 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 45 of Set 15 | pavilosta
# Processing Record 46 of Set 15 | siocon
# Processing Record 47 of Set 15 | abnub
# Processing Record 48 of Set 15 | kyra
# Processing Record 49 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 15 | astorga
# Processing Record 1 of Set 16 | calama
# Processing Record 2 of Set 16 | conakry
# Processing Record 3 of Set 16 | kampene
# Processing Record 4 of Set 16 | hualmay
# Processing Record 5 of Set 16 | horsham
# Processing Record 6 of Set 16 | rio de janeiro
# Processing Record 7 of Set 16 | nogliki
# Processing Record 8 of Set 16 | itambacuri
# Processing Record 9 of Set 16 | gizo
# Processing Record 10 of Set 16 | soe
# Processing Record 11 of Set 16 | koulamoutou
# Processing Record 12 of Set 16 | ponnani
# Processing Record 13 of Set 16 | mentok
# City not found. Skipping...
# Processing Record 14 of Set 16 | loding
# Processing Record 15 of Set 16 | nyimba
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Total Number of cities: 703

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

#Change the order of columns
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Winneba      GH   5.3511   -0.6231     82.87        84          89
# 1  Codrington      AU -38.2667  141.9667     63.03        46           0
# 2   Busselton      AU -33.6500  115.3333     80.55        31          31
# 3      Barrow      US  71.2906 -156.7887     17.62        67          75
# 4    Bengkulu      ID  -3.8004  102.2655     77.85        84         100
# 5     Rikitea      PF -23.1203 -134.9692     76.17        72          89
# 6   Fairbanks      US  64.8378 -147.7164     -7.76        71          90
# 7    Lakhipur      IN  26.0299   90.3041     71.91        69          37
# 8  Lavrentiya      RU  65.5833 -171.0000     25.18        96         100
# 9     Kichera      RU  55.9375  110.0997     20.98        81         100
#
#    Wind Speed Current Description
# 0        4.14     overcast clouds
# 1       14.32           clear sky
# 2        8.72    scattered clouds
# 3       21.85       broken clouds
# 4        6.82     overcast clouds
# 5        8.79     overcast clouds
# 6        0.00          light snow
# 7        6.76    scattered clouds
# 8       17.38                snow
# 9        7.40     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
